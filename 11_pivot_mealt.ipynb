# %%
import numpy as np
import pandas as pd

# %%
df_salaries=pd.read_csv("ds_salaries.csv", index_col=0)
df_salaries.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
df_salaries.pivot_table(index='job_title',columns='experience_level',values='salary')
# Out:
# experience_level                                     EN            EX  \
# job_title
# 3D Computer Vision Researcher                       NaN           NaN
# AI Scientist                              414750.000000           NaN
# Analytics Engineer                                  NaN  1.550000e+05
# Applied Data Scientist                     80000.000000           NaN
# Applied Machine Learning Scientist         29000.000000           NaN
# BI Data Analyst                            32136.000000  1.500000e+05
# Big Data Architect                                  NaN           NaN
# Big Data Engineer                         568333.333333           NaN
# Business Data Analyst                      75000.000000           NaN
# Cloud Data Engineer                                 NaN           NaN
# Computer Vision Engineer                  105000.000000           NaN
# Computer Vision Software Engineer         110000.000000           NaN
# ...

# %%
df_salaries.pivot_table(index='job_title',columns=['work_year', "experience_level"], values='salary_in_usd',aggfunc='mean').round(2)
# Out:
# work_year                                      2020                       \
# experience_level                                 EN        EX         MI
# job_title
# 3D Computer Vision Researcher                   NaN       NaN        NaN
# AI Scientist                               45896.00       NaN        NaN
# Analytics Engineer                              NaN       NaN        NaN
# Applied Data Scientist                          NaN       NaN        NaN
# Applied Machine Learning Scientist              NaN       NaN        NaN
# BI Data Analyst                                 NaN       NaN   98000.00
# Big Data Architect                              NaN       NaN        NaN
# Big Data Engineer                          70000.00       NaN        NaN
# Business Data Analyst                     100000.00       NaN  135000.00
# Cloud Data Engineer                             NaN       NaN        NaN
# Computer Vision Engineer                        NaN       NaN        NaN
# ...

# %%
df_salaries[['job_title','employee_residence']].head(5).melt()
# Out:
#              variable                       value
# 0           job_title              Data Scientist
# 1           job_title  Machine Learning Scientist
# 2           job_title           Big Data Engineer
# 3           job_title        Product Data Analyst
# 4           job_title   Machine Learning Engineer
# 5  employee_residence                          DE
# 6  employee_residence                          JP
# 7  employee_residence                          GB
# 8  employee_residence                          HN
# 9  employee_residence                          US

# %%
df_salaries.melt(id_vars='work_year',value_vars='job_title')
# Out:
#      work_year   variable                       value
# 0         2020  job_title              Data Scientist
# 1         2020  job_title  Machine Learning Scientist
# 2         2020  job_title           Big Data Engineer
# 3         2020  job_title        Product Data Analyst
# 4         2020  job_title   Machine Learning Engineer
# ..         ...        ...                         ...
# 602       2022  job_title               Data Engineer
# 603       2022  job_title               Data Engineer
# 604       2022  job_title                Data Analyst
# 605       2022  job_title                Data Analyst
# 606       2022  job_title                AI Scientist
#
# [607 rows x 3 columns]
